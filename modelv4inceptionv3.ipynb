# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.layers import Input, Dense, Flatten, Concatenate, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, LearningRateScheduler
import matplotlib.pyplot as plt
import json
import cv2
import logging

# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

LOG_FORMAT = "[%(asctime)s] [%(name)s] [%(levelname)s] %(message)s"
logging.basicConfig(format=LOG_FORMAT)
logging.getLogger("IMG").setLevel(logging.DEBUG)
log = logging.getLogger("IMG")

class PrintLogger(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} started.")
    
    def on_epoch_end(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} ended.")
        print(f"Accuracy: {logs['accuracy']:.4f} - Loss: {logs['loss']:.4f} - Val Accuracy: {logs['val_accuracy']:.4f} - Val Loss: {logs['val_loss']:.4f}")

class ImageBatcher:
    def __init__(self, images, batch_size: int, image_size: int, shuffle: bool, drop_last: bool, max_batch: int = 0) -> None:
        log.info("Initializing image batcher")
        self.images = images
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.max_batch = max_batch

        self.num_images = self.images.shape[0]
        self.shape = (batch_size, self.images.shape[1], image_size, image_size)
        self.size = int(np.prod(self.shape))
        self.dtype = self.images.dtype
        self.nbytes = self.dtype.itemsize * self.size

        log.debug(f"Image Fields... \
            \n\tNumber of images: {self.num_images} \
            \n\tType: {self.dtype} \
            \n\tBatch Shape: {self.shape} \
            \n\tBatch Size: {self.size} \
            \n\tBatch Bytes: {self.nbytes}")

        self.indices = None
        self.current_index = 0
        self.current_batch = 0
        self.epoch = 0
        self._initialize_indices()

        log.info("Successfully created image batcher")

    def _initialize_indices(self) -> None:
        log.debug(f"Initializing indices. Shuffle: {self.shuffle}")
        self.indices = np.arange(self.num_images)

        if self.shuffle:
            np.random.shuffle(self.indices)

    def __iter__(self):
        return self

    def __next__(self) -> np.ndarray:
        self.current_batch += 1

        if self.current_index >= self.num_images:
            self._batch_completed()
            raise StopIteration
        
        if self.max_batch != 0 and self.current_batch > self.max_batch:
            self._batch_completed()
            raise StopIteration
        
        start_idx = self.current_index
        end_idx = min(self.current_index + self.batch_size, self.num_images)
        batch_indices = self.indices[start_idx: end_idx]

        if self.drop_last and end_idx - start_idx != self.batch_size:
            log.debug("Skipped last batch")
            self._batch_completed()
            raise StopIteration
        
        batch_images = self._get_batch_from_dataset(batch_indices)

        self.current_index = end_idx
        return batch_images

    def _batch_completed(self) -> None:
        log.info("Batch completed")
        self.epoch += 1
        self.current_index = 0
        self.current_batch = 0

        if self.shuffle:
            np.random.shuffle(self.indices)

    def _get_batch_from_dataset(self, indices: list[int]) -> np.ndarray:
        if self.shuffle:
            batch_images = []
            for i in indices:
                batch_images.append(self.images[i])
            
            batch_images = np.stack(batch_images, axis=0)
            return self._preprocess_images(batch_images)
        else:
            batch_images = self.images[indices]
            return self._preprocess_images(batch_images)

    def _preprocess_images(self, images: np.ndarray) -> np.ndarray:
        output_size = (self.image_size, self.image_size)
        resized_images = np.empty((images.shape[0], *output_size, 3))
        resized_images = resized_images.astype(self.dtype)

        for i, image in enumerate(images):
            if image.shape[2] == 4:  # If image has 4 channels (RGBA), convert to 3 channels (RGB)
                image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
            resized_images[i] = cv2.resize(image, output_size, interpolation=cv2.INTER_LINEAR)
        
        return resized_images

# Function to resize images using the ImageBatcher
def resize_images_with_batcher(images, batch_size, image_size, shuffle=False):
    batcher = ImageBatcher(images, batch_size=batch_size, image_size=image_size, shuffle=shuffle, drop_last=False)
    resized_images = []

    for batch in batcher:
        resized_images.append(batch)

    return np.vstack(resized_images)

# Define directories
save_dir = './split_datav4'

# Load the split data
print("Loading data...")
X_rp_train = np.load(os.path.join(save_dir, 'X_rp_train.npy'))
X_gaf_train = np.load(os.path.join(save_dir, 'X_gaf_train.npy'))
X_mtf_train = np.load(os.path.join(save_dir, 'X_mtf_train.npy'))
y_train = np.load(os.path.join(save_dir, 'y_train.npy'))

X_rp_val = np.load(os.path.join(save_dir, 'X_rp_val.npy'))
X_gaf_val = np.load(os.path.join(save_dir, 'X_gaf_val.npy'))
X_mtf_val = np.load(os.path.join(save_dir, 'X_mtf_val.npy'))
y_val = np.load(os.path.join(save_dir, 'y_val.npy'))

X_rp_test = np.load(os.path.join(save_dir, 'X_rp_test.npy'))
X_gaf_test = np.load(os.path.join(save_dir, 'X_gaf_test.npy'))
X_mtf_test = np.load(os.path.join(save_dir, 'X_mtf_test.npy'))
y_test = np.load(os.path.join(save_dir, 'y_test.npy'))
print("Data loaded.")

print("Preprocessing images...")
X_rp_train = resize_images_with_batcher(X_rp_train, batch_size=32, image_size=224)
X_gaf_train = resize_images_with_batcher(X_gaf_train, batch_size=32, image_size=224)
X_mtf_train = resize_images_with_batcher(X_mtf_train, batch_size=32, image_size=224)
X_rp_val = resize_images_with_batcher(X_rp_val, batch_size=32, image_size=224)
X_gaf_val = resize_images_with_batcher(X_gaf_val, batch_size=32, image_size=224)
X_mtf_val = resize_images_with_batcher(X_mtf_val, batch_size=32, image_size=224)
X_rp_test = resize_images_with_batcher(X_rp_test, batch_size=32, image_size=224)
X_gaf_test = resize_images_with_batcher(X_gaf_test, batch_size=32, image_size=224)
X_mtf_test = resize_images_with_batcher(X_mtf_test, batch_size=32, image_size=224)
print("Images preprocessed.")

# Use a batch size of 32
batch_size = 32

# Generator to yield batches of data
def data_generator(X_rp, X_gaf, X_mtf, y, batch_size):
    num_samples = len(y)
    while True:
        for offset in range(0, num_samples, batch_size):
            X_rp_batch = X_rp[offset:offset+batch_size]
            X_gaf_batch = X_gaf[offset:offset+batch_size]
            X_mtf_batch = X_mtf[offset:offset+batch_size]
            y_batch = y[offset:offset+batch_size]
            yield ([X_rp_batch, X_gaf_batch, X_mtf_batch], y_batch)

train_gen = data_generator(X_rp_train, X_gaf_train, X_mtf_train, y_train, batch_size)
val_gen = data_generator(X_rp_val, X_gaf_val, X_mtf_val, y_val, batch_size)
test_gen = data_generator(X_rp_test, X_gaf_test, X_mtf_test, y_test, batch_size)

# Define a function to build the InceptionV3 model
def build_inceptionv3_model(input_shape, num_classes):
    inputs_rp = Input(shape=input_shape, name='input_rp')
    inputs_gaf = Input(shape=input_shape, name='input_gaf')
    inputs_mtf = Input(shape=input_shape, name='input_mtf')

    base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)

    base_rp = clone_model(base_model)
    base_rp._name = 'base_rp'
    base_rp.set_weights(base_model.get_weights())
    x_rp = base_rp(inputs_rp)
    x_rp = Flatten(name='flatten_rp')(x_rp)

    base_gaf = clone_model(base_model)
    base_gaf._name = 'base_gaf'
    base_gaf.set_weights(base_model.get_weights())
    x_gaf = base_gaf(inputs_gaf)
    x_gaf = Flatten(name='flatten_gaf')(x_gaf)

    base_mtf = clone_model(base_model)
    base_mtf._name = 'base_mtf'
    base_mtf.set_weights(base_model.get_weights())
    x_mtf = base_mtf(inputs_mtf)
    x_mtf = Flatten(name='flatten_mtf')(x_mtf)

    merged = Concatenate(name='concat')([x_rp, x_gaf, x_mtf])

    x = Dense(512, activation='relu', name='dense_512')(merged)
    x = Dropout(0.5, name='dropout_512')(x)
    x = Dense(128, activation='relu', name='dense_128')(x)
    x = Dropout(0.5, name='dropout_128')(x)
    outputs = Dense(num_classes, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs_rp, inputs_gaf, inputs_mtf], outputs=outputs)
    return model

# Define input shape and number of classes
input_shape = (224, 224, 3)
num_classes = 4  # Updated for 4 classes

# Build InceptionV3 model
inceptionv3_model = build_inceptionv3_model(input_shape, num_classes)
inceptionv3_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
                          loss='sparse_categorical_crossentropy', 
                          metrics=['accuracy'])

# Define early stopping and model checkpoint callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
inceptionv3_checkpoint = ModelCheckpoint(filepath=os.path.join(save_dir, 'inceptionv3_best_model.keras'), monitor='val_loss', save_best_only=True)

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler)

# Clear any existing TensorFlow sessions
tf.keras.backend.clear_session()

# Train InceptionV3 model
print("Starting training...")
steps_per_epoch = len(y_train) // batch_size
validation_steps = len(y_val) // batch_size
inceptionv3_history = inceptionv3_model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=10,
    validation_data=val_gen,
    validation_steps=validation_steps,
    callbacks=[early_stopping, inceptionv3_checkpoint, PrintLogger(), lr_scheduler],
    verbose=1
)

# Evaluate InceptionV3 model on the test set
print("Evaluating on test set...")
test_steps = len(y_test) // batch_size
inceptionv3_model.load_weights(os.path.join(save_dir, 'inceptionv3_best_model.keras'))
inceptionv3_test_loss, inceptionv3_test_accuracy = inceptionv3_model.evaluate(test_gen, steps=test_steps)
print(f'InceptionV3 Test loss: {inceptionv3_test_loss:.4f}')
print(f'InceptionV3 Test accuracy: {inceptionv3_test_accuracy:.4f}')

# Function to plot learning curves
def plot_learning_curve(history, model_name):
    plt.figure(figsize=(12, 8))

    # Plot training & validation accuracy values
    plt.subplot(2, 1, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'Model accuracy - {model_name}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(2, 1, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'Model loss - {model_name}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Plot learning curve for InceptionV3
plot_learning_curve(inceptionv3_history, 'InceptionV3')

# Save the final InceptionV3 model
inceptionv3_model.save(os.path.join(save_dir, 'inceptionv3_model.keras'))

# Save the training history
with open(os.path.join(save_dir, 'inceptionv3_history.json'), 'w') as f:
    json.dump(inceptionv3_history.history, f)

print(f"InceptionV3 model and history saved in directory: {save_dir}")
# Out:
# 2024-07-08 17:02:20.686059: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-08 17:02:20.716436: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 17:02:20.716458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 17:02:20.717211: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-08 17:02:20.722136: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPUs will likely run quickly with dtype policy mixed_float16 as they all have compute capability of at least 7.0
# Loading data...
# [2024-07-08 17:02:24,380] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:24,381] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:24,382] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:24,383] [IMG] [INFO] Successfully created image batcher
# Data loaded.
# Preprocessing images...
# [2024-07-08 17:02:25,560] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:25,823] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:25,824] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:25,824] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:25,825] [IMG] [INFO] Successfully created image batcher
# /tmp/ipykernel_361723/2535465295.py:119: RuntimeWarning: invalid value encountered in cast
#   resized_images = resized_images.astype(self.dtype)
# [2024-07-08 17:02:27,018] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:27,280] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:27,281] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:27,282] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:27,282] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:28,483] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:28,743] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:28,744] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:28,744] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:28,745] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:29,002] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:29,060] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:29,061] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:29,061] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:29,062] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:29,325] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:29,380] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:29,381] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:29,382] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:29,382] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:29,623] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:29,678] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:29,679] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:29,679] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:29,680] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:29,929] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:29,984] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:29,985] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:29,986] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:29,986] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:30,238] [IMG] [INFO] Batch completed
# [2024-07-08 17:02:30,294] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:02:30,294] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:02:30,295] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:02:30,295] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:02:30,546] [IMG] [INFO] Batch completed
# 2024-07-08 17:02:30.732789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8014 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:1a:00.0, compute capability: 8.6
# Images preprocessed.
# 2024-07-08 17:02:30.733318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7883 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:68:00.0, compute capability: 8.6
# Starting training...
#
# Epoch 1 started.
# Epoch 1/10
# 2024-07-08 17:03:26.534733: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
#   3/179 [..............................] - ETA: 25s - loss: 3.6257 - accuracy: 0.1042
# 2024-07-08 17:03:31.659081: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f95bc003710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-08 17:03:31.659145: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-07-08 17:03:31.659160: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-07-08 17:03:31.720991: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720483411.869078  361823 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 179/179 [==============================] - ETA: 0s - loss: 1.1642 - accuracy: 0.6411
# Epoch 1 ended.
# Accuracy: 0.6411 - Loss: 1.1642 - Val Accuracy: 0.7928 - Val Loss: 0.6262
# 179/179 [==============================] - 108s 318ms/step - loss: 1.1642 - accuracy: 0.6411 - val_loss: 0.6262 - val_accuracy: 0.7928 - lr: 1.0000e-04
#
# Epoch 2 started.
# Epoch 2/10
# 179/179 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.7636
# Epoch 2 ended.
# Accuracy: 0.7636 - Loss: 0.6734 - Val Accuracy: 0.8105 - Val Loss: 0.6684
# 179/179 [==============================] - 40s 205ms/step - loss: 0.6734 - accuracy: 0.7636 - val_loss: 0.6684 - val_accuracy: 0.8105 - lr: 1.0000e-04
#
# Epoch 3 started.
# Epoch 3/10
# 179/179 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.8067
# Epoch 3 ended.
# Accuracy: 0.8067 - Loss: 0.5456 - Val Accuracy: 0.8205 - Val Loss: 0.6883
# 179/179 [==============================] - 36s 201ms/step - loss: 0.5456 - accuracy: 0.8067 - val_loss: 0.6883 - val_accuracy: 0.8205 - lr: 1.0000e-04
#
# Epoch 4 started.
# Epoch 4/10
# 179/179 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.8344
# Epoch 4 ended.
# Accuracy: 0.8344 - Loss: 0.4769 - Val Accuracy: 0.8080 - Val Loss: 0.6726
# 179/179 [==============================] - 37s 205ms/step - loss: 0.4769 - accuracy: 0.8344 - val_loss: 0.6726 - val_accuracy: 0.8080 - lr: 1.0000e-04
# Evaluating on test set...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 269
#     267 print("Evaluating on test set...")
#     268 test_steps = len(y_test) // batch_size
# --> 269 inceptionv3_model.load_weights(os.path.join(save_dir, 'inceptionv3_best_model.keras'))
#     270 inceptionv3_test_loss, inceptionv3_test_accuracy = inceptionv3_model.evaluate(test_gen, steps=test_steps)
#     271 print(f'InceptionV3 Test loss: {inceptionv3_test_loss:.4f}')
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/engine/training.py:3235, in Model.load_weights(self, filepath, skip_mismatch, by_name, options)
#    3183 @traceback_utils.filter_traceback
#    3184 def load_weights(
#    3185     self, filepath, skip_mismatch=False, by_name=False, options=None
#    3186 ):
#    3187     """Loads all layer weights from a saved files.
#    3188
#    3189     The saved file could be a SavedModel file, a `.keras` file (v3 saving
#    (...)
#    3233             options for loading weights (only valid for a SavedModel file).
#    3234     """
# -> 3235     return saving_api.load_weights(
#    3236         self,
#    3237         filepath=filepath,
#    3238         by_name=by_name,
#    3239         skip_mismatch=skip_mismatch,
#    3240         options=options,
#    3241     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_api.py:297, in load_weights(model, filepath, skip_mismatch, **kwargs)
#     294     tf.io.gfile.copy(gs_filepath, filepath, overwrite=True)
#     296 if str(filepath).endswith(".keras") and zipfile.is_zipfile(filepath):
# --> 297     saving_lib.load_weights_only(
#     298         model, filepath, skip_mismatch=skip_mismatch
#     299     )
#     300 elif str(filepath).endswith(".weights.h5"):
#     301     saving_lib.load_weights_only(
#     302         model, filepath, skip_mismatch=skip_mismatch
#     303     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:333, in load_weights_only(model, filepath, skip_mismatch)
#     328     archive = zipfile.ZipFile(filepath, "r")
#     329     weights_store = H5IOStore(
#     330         _VARS_FNAME + ".h5", archive=archive, mode="r"
#     331     )
# --> 333 _load_state(
#     334     model,
#     335     weights_store=weights_store,
#     336     assets_store=None,
#     337     inner_path="",
#     338     skip_mismatch=skip_mismatch,
#     339     visited_trackables=set(),
#     340 )
#     341 weights_store.close()
#     342 if temp_dir and tf.io.gfile.exists(temp_dir):
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:466, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     457     _load_state(
#     458         child_obj,
#     459         weights_store,
#    (...)
#     463         visited_trackables=visited_trackables,
#     464     )
#     465 elif isinstance(child_obj, (list, dict, tuple, set)):
# --> 466     _load_container_state(
#     467         child_obj,
#     468         weights_store,
#     469         assets_store,
#     470         inner_path=tf.io.gfile.join(inner_path, child_attr),
#     471         skip_mismatch=skip_mismatch,
#     472         visited_trackables=visited_trackables,
#     473     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:534, in _load_container_state(container, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     532 else:
#     533     used_names[name] = 0
# --> 534 _load_state(
#     535     trackable,
#     536     weights_store,
#     537     assets_store,
#     538     inner_path=tf.io.gfile.join(inner_path, name),
#     539     skip_mismatch=skip_mismatch,
#     540     visited_trackables=visited_trackables,
#     541 )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:466, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     457     _load_state(
#     458         child_obj,
#     459         weights_store,
#    (...)
#     463         visited_trackables=visited_trackables,
#     464     )
#     465 elif isinstance(child_obj, (list, dict, tuple, set)):
# --> 466     _load_container_state(
#     467         child_obj,
#     468         weights_store,
#     469         assets_store,
#     470         inner_path=tf.io.gfile.join(inner_path, child_attr),
#     471         skip_mismatch=skip_mismatch,
#     472         visited_trackables=visited_trackables,
#     473     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:534, in _load_container_state(container, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     532 else:
#     533     used_names[name] = 0
# --> 534 _load_state(
#     535     trackable,
#     536     weights_store,
#     537     assets_store,
#     538     inner_path=tf.io.gfile.join(inner_path, name),
#     539     skip_mismatch=skip_mismatch,
#     540     visited_trackables=visited_trackables,
#     541 )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:435, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     428             warnings.warn(
#     429                 f"Could not load weights in object {trackable}. "
#     430                 "Skipping object. "
#     431                 f"Exception encountered: {e}",
#     432                 stacklevel=2,
#     433             )
#     434     else:
# --> 435         trackable.load_own_variables(weights_store.get(inner_path))
#     437 if hasattr(trackable, "load_assets") and assets_store:
#     438     if skip_mismatch:
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:633, in H5IOStore.get(self, path)
#     631 if not path:
#     632     return self.h5_file["vars"]
# --> 633 if path in self.h5_file and "vars" in self.h5_file[path]:
#     634     return self.h5_file[path]["vars"]
#     635 return {}
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/h5py/_hl/group.py:514, in Group.__contains__(self, name)
#     512     if not self.id:
#     513         return False
# --> 514     return h5g._path_valid(self.id, self._e(name), self._lapl)
#     515 return self._e(name) in self.id
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5g.pyx:531, in h5py.h5g._path_valid()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5l.pyx:212, in h5py.h5l.LinkProxy.exists()
#
# File h5py/h5fd.pyx:160, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:1123, in ZipExtFile.seek(self, offset, whence)
#    1121 while read_offset > 0:
#    1122     read_len = min(self.MAX_SEEK_READ, read_offset)
# -> 1123     self.read(read_len)
#    1124     read_offset -= read_len
#    1126 return self.tell()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:957, in ZipExtFile.read(self, n)
#     955 self._offset = 0
#     956 while n > 0 and not self._eof:
# --> 957     data = self._read1(n)
#     958     if n < len(data):
#     959         self._readbuffer = data
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:1047, in ZipExtFile._read1(self, n)
#    1045 if self._left <= 0:
#    1046     self._eof = True
# -> 1047 self._update_crc(data)
#    1048 return data
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:972, in ZipExtFile._update_crc(self, newdata)
#     969 if self._expected_crc is None:
#     970     # No need to compute the CRC if we don't have a reference value
#     971     return
# --> 972 self._running_crc = crc32(newdata, self._running_crc)
#     973 # Check the CRC if we're at the end of the file
#     974 if self._eof and self._running_crc != self._expected_crc:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.layers import Input, Dense, Flatten, Concatenate, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, LearningRateScheduler
import matplotlib.pyplot as plt
import json
import cv2
import logging

# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

LOG_FORMAT = "[%(asctime)s] [%(name)s] [%(levelname)s] %(message)s"
logging.basicConfig(format=LOG_FORMAT)
logging.getLogger("IMG").setLevel(logging.DEBUG)
log = logging.getLogger("IMG")

class PrintLogger(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} started.")
    
    def on_epoch_end(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} ended.")
        print(f"Accuracy: {logs['accuracy']:.4f} - Loss: {logs['loss']:.4f} - Val Accuracy: {logs['val_accuracy']:.4f} - Val Loss: {logs['val_loss']:.4f}")

class ImageBatcher:
    def __init__(self, images, batch_size: int, image_size: int, shuffle: bool, drop_last: bool, max_batch: int = 0) -> None:
        log.info("Initializing image batcher")
        self.images = images
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.max_batch = max_batch

        self.num_images = self.images.shape[0]
        self.shape = (batch_size, self.images.shape[1], image_size, image_size)
        self.size = int(np.prod(self.shape))
        self.dtype = self.images.dtype
        self.nbytes = self.dtype.itemsize * self.size

        log.debug(f"Image Fields... \
            \n\tNumber of images: {self.num_images} \
            \n\tType: {self.dtype} \
            \n\tBatch Shape: {self.shape} \
            \n\tBatch Size: {self.size} \
            \n\tBatch Bytes: {self.nbytes}")

        self.indices = None
        self.current_index = 0
        self.current_batch = 0
        self.epoch = 0
        self._initialize_indices()

        log.info("Successfully created image batcher")

    def _initialize_indices(self) -> None:
        log.debug(f"Initializing indices. Shuffle: {self.shuffle}")
        self.indices = np.arange(self.num_images)

        if self.shuffle:
            np.random.shuffle(self.indices)

    def __iter__(self):
        return self

    def __next__(self) -> np.ndarray:
        self.current_batch += 1

        if self.current_index >= self.num_images:
            self._batch_completed()
            raise StopIteration
        
        if self.max_batch != 0 and self.current_batch > self.max_batch:
            self._batch_completed()
            raise StopIteration
        
        start_idx = self.current_index
        end_idx = min(self.current_index + self.batch_size, self.num_images)
        batch_indices = self.indices[start_idx: end_idx]

        if self.drop_last and end_idx - start_idx != self.batch_size:
            log.debug("Skipped last batch")
            self._batch_completed()
            raise StopIteration
        
        batch_images = self._get_batch_from_dataset(batch_indices)

        self.current_index = end_idx
        return batch_images

    def _batch_completed(self) -> None:
        log.info("Batch completed")
        self.epoch += 1
        self.current_index = 0
        self.current_batch = 0

        if self.shuffle:
            np.random.shuffle(self.indices)

    def _get_batch_from_dataset(self, indices: list[int]) -> np.ndarray:
        if self.shuffle:
            batch_images = []
            for i in indices:
                batch_images.append(self.images[i])
            
            batch_images = np.stack(batch_images, axis=0)
            return self._preprocess_images(batch_images)
        else:
            batch_images = self.images[indices]
            return self._preprocess_images(batch_images)

    def _preprocess_images(self, images: np.ndarray) -> np.ndarray:
        output_size = (self.image_size, self.image_size)
        resized_images = np.empty((images.shape[0], *output_size, 3))
        resized_images = resized_images.astype(self.dtype)

        for i, image in enumerate(images):
            if image.shape[2] == 4:  # If image has 4 channels (RGBA), convert to 3 channels (RGB)
                image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
            resized_images[i] = cv2.resize(image, output_size, interpolation=cv2.INTER_LINEAR)
        
        return resized_images

# Function to resize images using the ImageBatcher
def resize_images_with_batcher(images, batch_size, image_size, shuffle=False):
    batcher = ImageBatcher(images, batch_size=batch_size, image_size=image_size, shuffle=shuffle, drop_last=False)
    resized_images = []

    for batch in batcher:
        resized_images.append(batch)

    return np.vstack(resized_images)

# Define directories
save_dir = './split_datav4'

# Load the split data
print("Loading data...")
X_rp_train = np.load(os.path.join(save_dir, 'X_rp_train.npy'))
X_gaf_train = np.load(os.path.join(save_dir, 'X_gaf_train.npy'))
X_mtf_train = np.load(os.path.join(save_dir, 'X_mtf_train.npy'))
y_train = np.load(os.path.join(save_dir, 'y_train.npy'))

X_rp_val = np.load(os.path.join(save_dir, 'X_rp_val.npy'))
X_gaf_val = np.load(os.path.join(save_dir, 'X_gaf_val.npy'))
X_mtf_val = np.load(os.path.join(save_dir, 'X_mtf_val.npy'))
y_val = np.load(os.path.join(save_dir, 'y_val.npy'))

X_rp_test = np.load(os.path.join(save_dir, 'X_rp_test.npy'))
X_gaf_test = np.load(os.path.join(save_dir, 'X_gaf_test.npy'))
X_mtf_test = np.load(os.path.join(save_dir, 'X_mtf_test.npy'))
y_test = np.load(os.path.join(save_dir, 'y_test.npy'))
print("Data loaded.")

print("Preprocessing images...")
X_rp_train = resize_images_with_batcher(X_rp_train, batch_size=32, image_size=224)
X_gaf_train = resize_images_with_batcher(X_gaf_train, batch_size=32, image_size=224)
X_mtf_train = resize_images_with_batcher(X_mtf_train, batch_size=32, image_size=224)
X_rp_val = resize_images_with_batcher(X_rp_val, batch_size=32, image_size=224)
X_gaf_val = resize_images_with_batcher(X_gaf_val, batch_size=32, image_size=224)
X_mtf_val = resize_images_with_batcher(X_mtf_val, batch_size=32, image_size=224)
X_rp_test = resize_images_with_batcher(X_rp_test, batch_size=32, image_size=224)
X_gaf_test = resize_images_with_batcher(X_gaf_test, batch_size=32, image_size=224)
X_mtf_test = resize_images_with_batcher(X_mtf_test, batch_size=32, image_size=224)
print("Images preprocessed.")

# Use a batch size of 32
batch_size = 32

# Generator to yield batches of data
def data_generator(X_rp, X_gaf, X_mtf, y, batch_size):
    num_samples = len(y)
    while True:
        for offset in range(0, num_samples, batch_size):
            X_rp_batch = X_rp[offset:offset+batch_size]
            X_gaf_batch = X_gaf[offset:offset+batch_size]
            X_mtf_batch = X_mtf[offset:offset+batch_size]
            y_batch = y[offset:offset+batch_size]
            yield ([X_rp_batch, X_gaf_batch, X_mtf_batch], y_batch)

train_gen = data_generator(X_rp_train, X_gaf_train, X_mtf_train, y_train, batch_size)
val_gen = data_generator(X_rp_val, X_gaf_val, X_mtf_val, y_val, batch_size)
test_gen = data_generator(X_rp_test, X_gaf_test, X_mtf_test, y_test, batch_size)

# Define a function to build the InceptionV3 model
def build_inceptionv3_model(input_shape, num_classes):
    inputs_rp = Input(shape=input_shape, name='input_rp')
    inputs_gaf = Input(shape=input_shape, name='input_gaf')
    inputs_mtf = Input(shape=input_shape, name='input_mtf')

    base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)

    base_rp = clone_model(base_model)
    base_rp._name = 'base_rp'
    base_rp.set_weights(base_model.get_weights())
    x_rp = base_rp(inputs_rp)
    x_rp = Flatten(name='flatten_rp')(x_rp)

    base_gaf = clone_model(base_model)
    base_gaf._name = 'base_gaf'
    base_gaf.set_weights(base_model.get_weights())
    x_gaf = base_gaf(inputs_gaf)
    x_gaf = Flatten(name='flatten_gaf')(x_gaf)

    base_mtf = clone_model(base_model)
    base_mtf._name = 'base_mtf'
    base_mtf.set_weights(base_model.get_weights())
    x_mtf = base_mtf(inputs_mtf)
    x_mtf = Flatten(name='flatten_mtf')(x_mtf)

    merged = Concatenate(name='concat')([x_rp, x_gaf, x_mtf])

    x = Dense(512, activation='relu', name='dense_512')(merged)
    x = Dropout(0.5, name='dropout_512')(x)
    x = Dense(128, activation='relu', name='dense_128')(x)
    x = Dropout(0.5, name='dropout_128')(x)
    outputs = Dense(num_classes, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs_rp, inputs_gaf, inputs_mtf], outputs=outputs)
    return model

# Define input shape and number of classes
input_shape = (224, 224, 3)
num_classes = 4  # Updated for 4 classes

# Build InceptionV3 model
inceptionv3_model = build_inceptionv3_model(input_shape, num_classes)
inceptionv3_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
                          loss='sparse_categorical_crossentropy', 
                          metrics=['accuracy'])

# Define early stopping and model checkpoint callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)  # Updated patience to 5
inceptionv3_checkpoint = ModelCheckpoint(filepath=os.path.join(save_dir, 'inceptionv3_best_model.keras'), monitor='val_loss', save_best_only=True)

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler)

# Clear any existing TensorFlow sessions
tf.keras.backend.clear_session()

# Train InceptionV3 model
print("Starting training...")
steps_per_epoch = len(y_train) // batch_size
validation_steps = len(y_val) // batch_size
inceptionv3_history = inceptionv3_model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=10,
    validation_data=val_gen,
    validation_steps=validation_steps,
    callbacks=[early_stopping, inceptionv3_checkpoint, PrintLogger(), lr_scheduler],
    verbose=1
)

# Evaluate InceptionV3 model on the test set
print("Evaluating on test set...")
test_steps = len(y_test) // batch_size
inceptionv3_model.load_weights(os.path.join(save_dir, 'inceptionv3_best_model.keras'))
inceptionv3_test_loss, inceptionv3_test_accuracy = inceptionv3_model.evaluate(test_gen, steps=test_steps)
print(f'InceptionV3 Test loss: {inceptionv3_test_loss:.4f}')
print(f'InceptionV3 Test accuracy: {inceptionv3_test_accuracy:.4f}')

# Function to plot learning curves
def plot_learning_curve(history, model_name):
    plt.figure(figsize=(12, 8))

    # Plot training & validation accuracy values
    plt.subplot(2, 1, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'Model accuracy - {model_name}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(2, 1, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'Model loss - {model_name}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Plot learning curve for InceptionV3
plot_learning_curve(inceptionv3_history, 'InceptionV3')

# Save the final InceptionV3 model
inceptionv3_model.save(os.path.join(save_dir, 'inceptionv3_model.keras'))

# Save the training history
with open(os.path.join(save_dir, 'inceptionv3_history.json'), 'w') as f:
    json.dump(inceptionv3_history.history, f)

print(f"InceptionV3 model and history saved in directory: {save_dir}")
# Out:
# Loading data...
# [2024-07-08 17:26:51,035] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:51,036] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:51,037] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:51,037] [IMG] [INFO] Successfully created image batcher
# Data loaded.
# Preprocessing images...
# /tmp/ipykernel_361723/276354052.py:119: RuntimeWarning: invalid value encountered in cast
#   resized_images = resized_images.astype(self.dtype)
# [2024-07-08 17:26:52,494] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:52,742] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:52,743] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:52,744] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:52,744] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:54,171] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:54,419] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:54,420] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:54,420] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:54,421] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:55,840] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:56,090] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:56,091] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:56,091] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:56,092] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:56,383] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:56,436] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:56,436] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:56,437] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:56,438] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:56,725] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:56,779] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:56,780] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:56,780] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:56,781] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:57,069] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:57,131] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:57,131] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:57,132] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:57,132] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:57,430] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:57,486] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:57,487] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:57,487] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:57,488] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:57,788] [IMG] [INFO] Batch completed
# [2024-07-08 17:26:57,843] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:26:57,844] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:26:57,845] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:26:57,845] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:26:58,150] [IMG] [INFO] Batch completed
# Images preprocessed.
# Starting training...
#
# Epoch 1 started.
# Epoch 1/10
# 179/179 [==============================] - ETA: 0s - loss: 1.1595 - accuracy: 0.6482
# Epoch 1 ended.
# Accuracy: 0.6482 - Loss: 1.1595 - Val Accuracy: 0.7771 - Val Loss: 0.7701
# 179/179 [==============================] - 111s 358ms/step - loss: 1.1595 - accuracy: 0.6482 - val_loss: 0.7701 - val_accuracy: 0.7771 - lr: 1.0000e-04
#
# Epoch 2 started.
# Epoch 2/10
# 179/179 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.7778
# Epoch 2 ended.
# Accuracy: 0.7778 - Loss: 0.6461 - Val Accuracy: 0.8139 - Val Loss: 0.5821
# 179/179 [==============================] - 45s 255ms/step - loss: 0.6461 - accuracy: 0.7778 - val_loss: 0.5821 - val_accuracy: 0.8139 - lr: 1.0000e-04
#
# Epoch 3 started.
# Epoch 3/10
# 179/179 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.8211
# Epoch 3 ended.
# Accuracy: 0.8211 - Loss: 0.5075 - Val Accuracy: 0.8005 - Val Loss: 0.6593
# 179/179 [==============================] - 37s 205ms/step - loss: 0.5075 - accuracy: 0.8211 - val_loss: 0.6593 - val_accuracy: 0.8005 - lr: 1.0000e-04
#
# Epoch 4 started.
# Epoch 4/10
# 179/179 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.8482
# Epoch 4 ended.
# Accuracy: 0.8482 - Loss: 0.4171 - Val Accuracy: 0.7938 - Val Loss: 0.6622
# 179/179 [==============================] - 37s 206ms/step - loss: 0.4171 - accuracy: 0.8482 - val_loss: 0.6622 - val_accuracy: 0.7938 - lr: 1.0000e-04
#
# Epoch 5 started.
# Epoch 5/10
# 179/179 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8679
# Epoch 5 ended.
# Accuracy: 0.8679 - Loss: 0.3691 - Val Accuracy: 0.8038 - Val Loss: 0.7659
# 179/179 [==============================] - 37s 207ms/step - loss: 0.3691 - accuracy: 0.8679 - val_loss: 0.7659 - val_accuracy: 0.8038 - lr: 1.0000e-04
#
# Epoch 6 started.
# Epoch 6/10
# 179/179 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8889
# Epoch 6 ended.
# Accuracy: 0.8889 - Loss: 0.3003 - Val Accuracy: 0.8172 - Val Loss: 0.7416
# 179/179 [==============================] - 37s 206ms/step - loss: 0.3003 - accuracy: 0.8889 - val_loss: 0.7416 - val_accuracy: 0.8172 - lr: 9.0484e-05
#
# Epoch 7 started.
# Epoch 7/10
# 179/179 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.9187
# Epoch 7 ended.
# Accuracy: 0.9187 - Loss: 0.2341 - Val Accuracy: 0.8139 - Val Loss: 0.9796
# 179/179 [==============================] - 37s 208ms/step - loss: 0.2341 - accuracy: 0.9187 - val_loss: 0.9796 - val_accuracy: 0.8139 - lr: 8.1873e-05
# Evaluating on test set...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 269
#     267 print("Evaluating on test set...")
#     268 test_steps = len(y_test) // batch_size
# --> 269 inceptionv3_model.load_weights(os.path.join(save_dir, 'inceptionv3_best_model.keras'))
#     270 inceptionv3_test_loss, inceptionv3_test_accuracy = inceptionv3_model.evaluate(test_gen, steps=test_steps)
#     271 print(f'InceptionV3 Test loss: {inceptionv3_test_loss:.4f}')
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/engine/training.py:3235, in Model.load_weights(self, filepath, skip_mismatch, by_name, options)
#    3183 @traceback_utils.filter_traceback
#    3184 def load_weights(
#    3185     self, filepath, skip_mismatch=False, by_name=False, options=None
#    3186 ):
#    3187     """Loads all layer weights from a saved files.
#    3188
#    3189     The saved file could be a SavedModel file, a `.keras` file (v3 saving
#    (...)
#    3233             options for loading weights (only valid for a SavedModel file).
#    3234     """
# -> 3235     return saving_api.load_weights(
#    3236         self,
#    3237         filepath=filepath,
#    3238         by_name=by_name,
#    3239         skip_mismatch=skip_mismatch,
#    3240         options=options,
#    3241     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_api.py:297, in load_weights(model, filepath, skip_mismatch, **kwargs)
#     294     tf.io.gfile.copy(gs_filepath, filepath, overwrite=True)
#     296 if str(filepath).endswith(".keras") and zipfile.is_zipfile(filepath):
# --> 297     saving_lib.load_weights_only(
#     298         model, filepath, skip_mismatch=skip_mismatch
#     299     )
#     300 elif str(filepath).endswith(".weights.h5"):
#     301     saving_lib.load_weights_only(
#     302         model, filepath, skip_mismatch=skip_mismatch
#     303     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:333, in load_weights_only(model, filepath, skip_mismatch)
#     328     archive = zipfile.ZipFile(filepath, "r")
#     329     weights_store = H5IOStore(
#     330         _VARS_FNAME + ".h5", archive=archive, mode="r"
#     331     )
# --> 333 _load_state(
#     334     model,
#     335     weights_store=weights_store,
#     336     assets_store=None,
#     337     inner_path="",
#     338     skip_mismatch=skip_mismatch,
#     339     visited_trackables=set(),
#     340 )
#     341 weights_store.close()
#     342 if temp_dir and tf.io.gfile.exists(temp_dir):
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:466, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     457     _load_state(
#     458         child_obj,
#     459         weights_store,
#    (...)
#     463         visited_trackables=visited_trackables,
#     464     )
#     465 elif isinstance(child_obj, (list, dict, tuple, set)):
# --> 466     _load_container_state(
#     467         child_obj,
#     468         weights_store,
#     469         assets_store,
#     470         inner_path=tf.io.gfile.join(inner_path, child_attr),
#     471         skip_mismatch=skip_mismatch,
#     472         visited_trackables=visited_trackables,
#     473     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:534, in _load_container_state(container, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     532 else:
#     533     used_names[name] = 0
# --> 534 _load_state(
#     535     trackable,
#     536     weights_store,
#     537     assets_store,
#     538     inner_path=tf.io.gfile.join(inner_path, name),
#     539     skip_mismatch=skip_mismatch,
#     540     visited_trackables=visited_trackables,
#     541 )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:466, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     457     _load_state(
#     458         child_obj,
#     459         weights_store,
#    (...)
#     463         visited_trackables=visited_trackables,
#     464     )
#     465 elif isinstance(child_obj, (list, dict, tuple, set)):
# --> 466     _load_container_state(
#     467         child_obj,
#     468         weights_store,
#     469         assets_store,
#     470         inner_path=tf.io.gfile.join(inner_path, child_attr),
#     471         skip_mismatch=skip_mismatch,
#     472         visited_trackables=visited_trackables,
#     473     )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:534, in _load_container_state(container, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     532 else:
#     533     used_names[name] = 0
# --> 534 _load_state(
#     535     trackable,
#     536     weights_store,
#     537     assets_store,
#     538     inner_path=tf.io.gfile.join(inner_path, name),
#     539     skip_mismatch=skip_mismatch,
#     540     visited_trackables=visited_trackables,
#     541 )
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:435, in _load_state(trackable, weights_store, assets_store, inner_path, skip_mismatch, visited_trackables)
#     428             warnings.warn(
#     429                 f"Could not load weights in object {trackable}. "
#     430                 "Skipping object. "
#     431                 f"Exception encountered: {e}",
#     432                 stacklevel=2,
#     433             )
#     434     else:
# --> 435         trackable.load_own_variables(weights_store.get(inner_path))
#     437 if hasattr(trackable, "load_assets") and assets_store:
#     438     if skip_mismatch:
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/keras/src/engine/base_layer.py:3539, in Layer.load_own_variables(self, store)
#    3531     raise ValueError(
#    3532         f"Layer '{self.name}' expected {len(all_vars)} variables, "
#    3533         "but received "
#    3534         f"{len(store.keys())} variables during loading. "
#    3535         f"Expected: {[v.name for v in all_vars]}"
#    3536     )
#    3537 for i, v in enumerate(all_vars):
#    3538     # TODO(rchao): check shapes and raise errors.
# -> 3539     v.assign(store[f"{i}"])
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:241, in h5py.h5o.open()
#
# File h5py/h5fd.pyx:160, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:1123, in ZipExtFile.seek(self, offset, whence)
#    1121 while read_offset > 0:
#    1122     read_len = min(self.MAX_SEEK_READ, read_offset)
# -> 1123     self.read(read_len)
#    1124     read_offset -= read_len
#    1126 return self.tell()
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:957, in ZipExtFile.read(self, n)
#     955 self._offset = 0
#     956 while n > 0 and not self._eof:
# --> 957     data = self._read1(n)
#     958     if n < len(data):
#     959         self._readbuffer = data
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:1027, in ZipExtFile._read1(self, n)
#    1025         data += self._read2(n - len(data))
#    1026 else:
# -> 1027     data = self._read2(n)
#    1029 if self._compress_type == ZIP_STORED:
#    1030     self._eof = self._compress_left <= 0
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:1057, in ZipExtFile._read2(self, n)
#    1054 n = max(n, self.MIN_READ_SIZE)
#    1055 n = min(n, self._compress_left)
# -> 1057 data = self._fileobj.read(n)
#    1058 self._compress_left -= len(data)
#    1059 if not data:
#
# File ~/miniconda3/envs/newtest/lib/python3.11/zipfile.py:777, in _SharedFile.read(self, n)
#     773     raise ValueError("Can't read from the ZIP file while there "
#     774             "is an open writing handle on it. "
#     775             "Close the writing handle before trying to read.")
#     776 self._file.seek(self._pos)
# --> 777 data = self._file.read(n)
#     778 self._pos = self._file.tell()
#     779 return data
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model, clone_model, load_model
from tensorflow.keras.layers import Input, Dense, Flatten, Concatenate, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, LearningRateScheduler
import matplotlib.pyplot as plt
import json
import cv2
import logging
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
import seaborn as sns

# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

LOG_FORMAT = "[%(asctime)s] [%(name)s] [%(levelname)s] %(message)s"
logging.basicConfig(format=LOG_FORMAT)
logging.getLogger("IMG").setLevel(logging.DEBUG)
log = logging.getLogger("IMG")

class PrintLogger(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} started.")
    
    def on_epoch_end(self, epoch, logs=None):
        print(f"\nEpoch {epoch + 1} ended.")
        print(f"Accuracy: {logs['accuracy']:.4f} - Loss: {logs['loss']:.4f} - Val Accuracy: {logs['val_accuracy']:.4f} - Val Loss: {logs['val_loss']:.4f}")

class ImageBatcher:
    def __init__(self, images, batch_size: int, image_size: int, shuffle: bool, drop_last: bool, max_batch: int = 0) -> None:
        log.info("Initializing image batcher")
        self.images = images
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.max_batch = max_batch

        self.num_images = self.images.shape[0]
        self.shape = (batch_size, self.images.shape[1], image_size, image_size)
        self.size = int(np.prod(self.shape))
        self.dtype = self.images.dtype
        self.nbytes = self.dtype.itemsize * self.size

        log.debug(f"Image Fields... \
            \n\tNumber of images: {self.num_images} \
            \n\tType: {self.dtype} \
            \n\tBatch Shape: {self.shape} \
            \n\tBatch Size: {self.size} \
            \n\tBatch Bytes: {self.nbytes}")

        self.indices = None
        self.current_index = 0
        self.current_batch = 0
        self.epoch = 0
        self._initialize_indices()

        log.info("Successfully created image batcher")

    def _initialize_indices(self) -> None:
        log.debug(f"Initializing indices. Shuffle: {self.shuffle}")
        self.indices = np.arange(self.num_images)

        if self.shuffle:
            np.random.shuffle(self.indices)

    def __iter__(self):
        return self

    def __next__(self) -> np.ndarray:
        self.current_batch += 1

        if self.current_index >= self.num_images:
            self._batch_completed()
            raise StopIteration
        
        if self.max_batch != 0 and self.current_batch > self.max_batch:
            self._batch_completed()
            raise StopIteration
        
        start_idx = self.current_index
        end_idx = min(self.current_index + self.batch_size, self.num_images)
        batch_indices = self.indices[start_idx: end_idx]

        if self.drop_last and end_idx - start_idx != self.batch_size:
            log.debug("Skipped last batch")
            self._batch_completed()
            raise StopIteration
        
        batch_images = self._get_batch_from_dataset(batch_indices)

        self.current_index = end_idx
        return batch_images

    def _batch_completed(self) -> None:
        log.info("Batch completed")
        self.epoch += 1
        self.current_index = 0
        self.current_batch = 0

        if self.shuffle:
            np.random.shuffle(self.indices)

    def _get_batch_from_dataset(self, indices: list[int]) -> np.ndarray:
        if self.shuffle:
            batch_images = []
            for i in indices:
                batch_images.append(self.images[i])
            
            batch_images = np.stack(batch_images, axis=0)
            return self._preprocess_images(batch_images)
        else:
            batch_images = self.images[indices]
            return self._preprocess_images(batch_images)

    def _preprocess_images(self, images: np.ndarray) -> np.ndarray:
        output_size = (self.image_size, self.image_size)
        resized_images = np.empty((images.shape[0], *output_size, 3))
        resized_images = resized_images.astype(self.dtype)

        for i, image in enumerate(images):
            if image.shape[2] == 4:  # If image has 4 channels (RGBA), convert to 3 channels (RGB)
                image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
            resized_images[i] = cv2.resize(image, output_size, interpolation=cv2.INTER_LINEAR)
        
        return resized_images

# Function to resize images using the ImageBatcher
def resize_images_with_batcher(images, batch_size, image_size, shuffle=False):
    batcher = ImageBatcher(images, batch_size=batch_size, image_size=image_size, shuffle=shuffle, drop_last=False)
    resized_images = []

    for batch in batcher:
        resized_images.append(batch)

    return np.vstack(resized_images)

# Define directories
save_dir = './split_datav4'

# Load the split data
print("Loading data...")
X_rp_train = np.load(os.path.join(save_dir, 'X_rp_train.npy'))
X_gaf_train = np.load(os.path.join(save_dir, 'X_gaf_train.npy'))
X_mtf_train = np.load(os.path.join(save_dir, 'X_mtf_train.npy'))
y_train = np.load(os.path.join(save_dir, 'y_train.npy'))

X_rp_val = np.load(os.path.join(save_dir, 'X_rp_val.npy'))
X_gaf_val = np.load(os.path.join(save_dir, 'X_gaf_val.npy'))
X_mtf_val = np.load(os.path.join(save_dir, 'X_mtf_val.npy'))
y_val = np.load(os.path.join(save_dir, 'y_val.npy'))

X_rp_test = np.load(os.path.join(save_dir, 'X_rp_test.npy'))
X_gaf_test = np.load(os.path.join(save_dir, 'X_gaf_test.npy'))
X_mtf_test = np.load(os.path.join(save_dir, 'X_mtf_test.npy'))
y_test = np.load(os.path.join(save_dir, 'y_test.npy'))
print("Data loaded.")

print("Preprocessing images...")
X_rp_train = resize_images_with_batcher(X_rp_train, batch_size=32, image_size=224)
X_gaf_train = resize_images_with_batcher(X_gaf_train, batch_size=32, image_size=224)
X_mtf_train = resize_images_with_batcher(X_mtf_train, batch_size=32, image_size=224)
X_rp_val = resize_images_with_batcher(X_rp_val, batch_size=32, image_size=224)
X_gaf_val = resize_images_with_batcher(X_gaf_val, batch_size=32, image_size=224)
X_mtf_val = resize_images_with_batcher(X_mtf_val, batch_size=32, image_size=224)
X_rp_test = resize_images_with_batcher(X_rp_test, batch_size=32, image_size=224)
X_gaf_test = resize_images_with_batcher(X_gaf_test, batch_size=32, image_size=224)
X_mtf_test = resize_images_with_batcher(X_mtf_test, batch_size=32, image_size=224)
print("Images preprocessed.")

# Use a batch size of 32
batch_size = 32

# Generator to yield batches of data
def data_generator(X_rp, X_gaf, X_mtf, y, batch_size):
    num_samples = len(y)
    while True:
        for offset in range(0, num_samples, batch_size):
            X_rp_batch = X_rp[offset:offset+batch_size]
            X_gaf_batch = X_gaf[offset:offset+batch_size]
            X_mtf_batch = X_mtf[offset:offset+batch_size]
            y_batch = y[offset:offset+batch_size]
            yield ([X_rp_batch, X_gaf_batch, X_mtf_batch], y_batch)

train_gen = data_generator(X_rp_train, X_gaf_train, X_mtf_train, y_train, batch_size)
val_gen = data_generator(X_rp_val, X_gaf_val, X_mtf_val, y_val, batch_size)
test_gen = data_generator(X_rp_test, X_gaf_test, X_mtf_test, y_test, batch_size)

# Define a function to build the InceptionV3 model
def build_inceptionv3_model(input_shape, num_classes):
    inputs_rp = Input(shape=input_shape, name='input_rp')
    inputs_gaf = Input(shape=input_shape, name='input_gaf')
    inputs_mtf = Input(shape=input_shape, name='input_mtf')

    base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)

    base_rp = clone_model(base_model)
    base_rp._name = 'base_rp'
    base_rp.set_weights(base_model.get_weights())
    x_rp = base_rp(inputs_rp)
    x_rp = Flatten(name='flatten_rp')(x_rp)

    base_gaf = clone_model(base_model)
    base_gaf._name = 'base_gaf'
    base_gaf.set_weights(base_model.get_weights())
    x_gaf = base_gaf(inputs_gaf)
    x_gaf = Flatten(name='flatten_gaf')(x_gaf)

    base_mtf = clone_model(base_model)
    base_mtf._name = 'base_mtf'
    base_mtf.set_weights(base_model.get_weights())
    x_mtf = base_mtf(inputs_mtf)
    x_mtf = Flatten(name='flatten_mtf')(x_mtf)

    merged = Concatenate(name='concat')([x_rp, x_gaf, x_mtf])

    x = Dense(512, activation='relu', name='dense_512')(merged)
    x = Dropout(0.5, name='dropout_512')(x)
    x = Dense(128, activation='relu', name='dense_128')(x)
    x = Dropout(0.5, name='dropout_128')(x)
    outputs = Dense(num_classes, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs_rp, inputs_gaf, inputs_mtf], outputs=outputs)
    return model

# Define input shape and number of classes
input_shape = (224, 224, 3)
num_classes = 4  # Updated for 4 classes

# Build InceptionV3 model
inceptionv3_model = build_inceptionv3_model(input_shape, num_classes)
inceptionv3_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
                          loss='sparse_categorical_crossentropy', 
                          metrics=['accuracy'])

# Define early stopping and model checkpoint callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)  # Updated patience to 5
inceptionv3_checkpoint = ModelCheckpoint(filepath=os.path.join(save_dir, 'inceptionv3_best_model.keras'), monitor='val_loss', save_best_only=True)

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler)

# Clear any existing TensorFlow sessions
tf.keras.backend.clear_session()

# Train InceptionV3 model
print("Starting training...")
steps_per_epoch = len(y_train) // batch_size
validation_steps = len(y_val) // batch_size
inceptionv3_history = inceptionv3_model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    epochs=10,
    validation_data=val_gen,
    validation_steps=validation_steps,
    callbacks=[early_stopping, inceptionv3_checkpoint, PrintLogger(), lr_scheduler],
    verbose=1
)

# Evaluate InceptionV3 model on the test set
print("Evaluating on test set...")
test_steps = len(y_test) // batch_size
inceptionv3_model.load_weights(os.path.join(save_dir, 'inceptionv3_best_model.keras'))
inceptionv3_test_loss, inceptionv3_test_accuracy = inceptionv3_model.evaluate(test_gen, steps=test_steps)
print(f'InceptionV3 Test loss: {inceptionv3_test_loss:.4f}')
print(f'InceptionV3 Test accuracy: {inceptionv3_test_accuracy:.4f}')

# Function to plot learning curves
def plot_learning_curve(history, model_name):
    plt.figure(figsize=(12, 8))

    # Plot training & validation accuracy values
    plt.subplot(2, 1, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'Model accuracy - {model_name}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(2, 1, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'Model loss - {model_name}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Plot learning curve for InceptionV3
plot_learning_curve(inceptionv3_history, 'InceptionV3')

# Save the final InceptionV3 model
inceptionv3_model.save(os.path.join(save_dir, 'inceptionv3_model.keras'))

# Save the training history
with open(os.path.join(save_dir, 'inceptionv3_history.json'), 'w') as f:
    json.dump(inceptionv3_history.history, f)

print(f"InceptionV3 model and history saved in directory: {save_dir}")
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPUs will likely run quickly with dtype policy mixed_float16 as they all have compute capability of at least 7.0
# Loading data...
# [2024-07-08 17:51:28,847] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:28,847] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:28,848] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:28,849] [IMG] [INFO] Successfully created image batcher
# Data loaded.
# Preprocessing images...
# [2024-07-08 17:51:30,059] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:30,325] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:30,326] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:30,327] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:30,327] [IMG] [INFO] Successfully created image batcher
# /tmp/ipykernel_392808/2944972140.py:121: RuntimeWarning: invalid value encountered in cast
#   resized_images = resized_images.astype(self.dtype)
# [2024-07-08 17:51:31,541] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:31,806] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:31,807] [IMG] [DEBUG] Image Fields...
# 	Number of images: 5738
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:31,808] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:31,808] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:32,968] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:33,222] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:33,223] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:33,224] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:33,224] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:33,473] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:33,529] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:33,530] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:33,531] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:33,531] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:33,778] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:33,834] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:33,835] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:33,836] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:33,836] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:34,078] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:34,134] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:34,135] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:34,136] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:34,136] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:34,379] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:34,435] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:34,436] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:34,437] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:34,437] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:34,729] [IMG] [INFO] Batch completed
# [2024-07-08 17:51:34,788] [IMG] [INFO] Initializing image batcher
# [2024-07-08 17:51:34,789] [IMG] [DEBUG] Image Fields...
# 	Number of images: 1230
# 	Type: uint8
# 	Batch Shape: (32, 201, 224, 224)
# 	Batch Size: 322732032
# 	Batch Bytes: 322732032
# [2024-07-08 17:51:34,790] [IMG] [DEBUG] Initializing indices. Shuffle: False
# [2024-07-08 17:51:34,790] [IMG] [INFO] Successfully created image batcher
# [2024-07-08 17:51:35,049] [IMG] [INFO] Batch completed
# 2024-07-08 17:51:35.127646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8014 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:1a:00.0, compute capability: 8.6
# 2024-07-08 17:51:35.127770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7883 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:68:00.0, compute capability: 8.6
# Images preprocessed.
# Starting training...
#
# Epoch 1 started.
# Epoch 1/10
# 2024-07-08 17:52:30.688028: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
#   2/179 [..............................] - ETA: 26s - loss: 2.2129 - accuracy: 0.2812
# 2024-07-08 17:52:35.687056: I external/local_xla/xla/service/service.cc:168] XLA service 0x7ff520003750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-08 17:52:35.687112: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-07-08 17:52:35.687124: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-07-08 17:52:35.760274: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720486355.916773  392921 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 179/179 [==============================] - ETA: 0s - loss: 1.2566 - accuracy: 0.6323
# Epoch 1 ended.
# Accuracy: 0.6323 - Loss: 1.2566 - Val Accuracy: 0.7558 - Val Loss: 0.7006
# 179/179 [==============================] - 102s 284ms/step - loss: 1.2566 - accuracy: 0.6323 - val_loss: 0.7006 - val_accuracy: 0.7558 - lr: 1.0000e-04
#
# Epoch 2 started.
# Epoch 2/10
# 179/179 [==============================] - ETA: 0s - loss: 0.6795 - accuracy: 0.7652
# Epoch 2 ended.
# Accuracy: 0.7652 - Loss: 0.6795 - Val Accuracy: 0.8022 - Val Loss: 0.6785
# 179/179 [==============================] - 48s 252ms/step - loss: 0.6795 - accuracy: 0.7652 - val_loss: 0.6785 - val_accuracy: 0.8022 - lr: 1.0000e-04
#
# Epoch 3 started.
# Epoch 3/10
# 179/179 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.7979
# Epoch 3 ended.
# Accuracy: 0.7979 - Loss: 0.5806 - Val Accuracy: 0.8155 - Val Loss: 0.6007
# 179/179 [==============================] - 45s 250ms/step - loss: 0.5806 - accuracy: 0.7979 - val_loss: 0.6007 - val_accuracy: 0.8155 - lr: 1.0000e-04
#
# Epoch 4 started.
# Epoch 4/10
# 179/179 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.8274
# Epoch 4 ended.
# Accuracy: 0.8274 - Loss: 0.4935 - Val Accuracy: 0.8139 - Val Loss: 0.7951
# 179/179 [==============================] - 35s 196ms/step - loss: 0.4935 - accuracy: 0.8274 - val_loss: 0.7951 - val_accuracy: 0.8139 - lr: 1.0000e-04
#
# Epoch 5 started.
# Epoch 5/10
# 179/179 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.8453
# Epoch 5 ended.
# Accuracy: 0.8453 - Loss: 0.4617 - Val Accuracy: 0.7713 - Val Loss: 0.9966
# 179/179 [==============================] - 35s 198ms/step - loss: 0.4617 - accuracy: 0.8453 - val_loss: 0.9966 - val_accuracy: 0.7713 - lr: 1.0000e-04
#
# Epoch 6 started.
# Epoch 6/10
# 179/179 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.8617
# Epoch 6 ended.
# Accuracy: 0.8617 - Loss: 0.4081 - Val Accuracy: 0.7830 - Val Loss: 0.8495
# 179/179 [==============================] - 35s 198ms/step - loss: 0.4081 - accuracy: 0.8617 - val_loss: 0.8495 - val_accuracy: 0.7830 - lr: 9.0484e-05
#
# Epoch 7 started.
# Epoch 7/10
# 179/179 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8905
# Epoch 7 ended.
# Accuracy: 0.8905 - Loss: 0.2960 - Val Accuracy: 0.7980 - Val Loss: 0.8963
# 179/179 [==============================] - 35s 198ms/step - loss: 0.2960 - accuracy: 0.8905 - val_loss: 0.8963 - val_accuracy: 0.7980 - lr: 8.1873e-05
#
# Epoch 8 started.
# Epoch 8/10
# 179/179 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9232
# Epoch 8 ended.
# Accuracy: 0.9232 - Loss: 0.2114 - Val Accuracy: 0.8022 - Val Loss: 1.0680
# 179/179 [==============================] - 36s 201ms/step - loss: 0.2114 - accuracy: 0.9232 - val_loss: 1.0680 - val_accuracy: 0.8022 - lr: 7.4082e-05
# Evaluating on test set...
# 38/38 [==============================] - 2s 49ms/step - loss: 0.5980 - accuracy: 0.8026
# InceptionV3 Test loss: 0.5980
# InceptionV3 Test accuracy: 0.8026
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 309
#     307 # Save the training history
#     308 with open(os.path.join(save_dir, 'inceptionv3_history.json'), 'w') as f:
# --> 309     json.dump(inceptionv3_history.history, f)
#     311 print(f"InceptionV3 model and history saved in directory: {save_dir}")
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File ~/miniconda3/envs/newtest/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type float32 is not JSON serializable

# %%
import gc
import tensorflow as tf
from tensorflow.keras import backend as K

# Trigger garbage collection
gc.collect()

# Clear TensorFlow session
K.clear_session()

# Reset the default graph (for TensorFlow 1.x)
tf.compat.v1.reset_default_graph()

# Free up memory in TensorFlow
tf.compat.v1.Session().close()

# Alternatively, use the following if you are using TensorFlow 2.x:
tf.keras.backend.clear_session()
# Out:
# 2024-07-08 17:51:14.687901: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-08 17:51:14.717435: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 17:51:14.717459: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 17:51:14.718183: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-08 17:51:14.723009: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-08 17:51:16.341624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8014 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:1a:00.0, compute capability: 8.6
# 2024-07-08 17:51:16.342125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7883 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:68:00.0, compute capability: 8.6
